# %%
import torch

# %%
import models
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9ab2fda4397b> in <module>
# ----> 1 import models
#
# ModuleNotFoundError: No module named 'models'

# %%
from networks.superpixel import modelssp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-7c42fcd7fe64> in <module>
# ----> 1 from networks.superpixel import modelssp
#
# ModuleNotFoundError: No module named 'networks'

# %%
model = models.__dict__['SpixelNet1l_bn']

# %%
model
# Out:
# <function models.Spixel_single_layer.SpixelNet1l_bn(data=None)>

# %%
image = torch.randn(3,3,128,128)

# %%
net = model()
out = net (image)

# %%
out.shape
# Out:
# torch.Size([3, 9, 128, 128])

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(out[1][8].detach().numpy())

# %%
plt.imshow(image[1][2].detach().numpy())
